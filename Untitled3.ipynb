# %%
from collections import deque

def bfs_shortest_path(graph, start, goal):
    # Create a queue for BFS and a set to track visited cities
    queue = deque([(start, [start])])  # (current city, path taken to reach it)
    visited = set()

    while queue:
        current_city, path = queue.popleft()  # Get the first city and its path

        # Check if we reached the goal
        if current_city == goal:
            return path  # Return the path if we reach Karachi

        # If the city has not been visited yet
        if current_city not in visited:
            visited.add(current_city)  # Mark it as visited

            # Enqueue all connected cities to the queue
            for neighbor in graph[current_city]:
                if neighbor not in visited:
                    queue.append((neighbor, path + [neighbor]))

    return None  # If no path found

# Define the graph with cities and their connections
cities_graph = {
    "Islamabad": ["Rawalpindi", "Lahore", "Peshawar"],
    "Rawalpindi": ["Islamabad", "Peshawar", "Quetta"],
    "Peshawar": ["Islamabad", "Rawalpindi", "Quetta"],
    "Lahore": ["Islamabad", "Multan", "Quetta"],
    "Multan": ["Lahore", "Karachi", "Quetta"],
    "Quetta": ["Rawalpindi", "Peshawar", "Multan", "Karachi"],
    "Karachi": ["Multan", "Quetta"]
}

# Find the shortest path from Islamabad to Karachi
shortest_path = bfs_shortest_path(cities_graph, "Islamabad", "Karachi")

# Output the result
if shortest_path:
    print("Shortest path from Islamabad to Karachi:", " -> ".join(shortest_path))
else:
    print("No path found from Islamabad to Karachi.")
# Out:
# Shortest path from Islamabad to Karachi: Islamabad -> Rawalpindi -> Quetta -> Karachi

# %%
import matplotlib.pyplot as plt

# Define the graph with cities and their connections
cities_graph = {
    "Islamabad": ["Rawalpindi", "Lahore", "Peshawar"],
    "Rawalpindi": ["Islamabad", "Peshawar", "Quetta"],
    "Peshawar": ["Islamabad", "Rawalpindi", "Quetta"],
    "Lahore": ["Islamabad", "Multan", "Quetta"],
    "Multan": ["Lahore", "Karachi", "Quetta"],
    "Quetta": ["Rawalpindi", "Peshawar", "Multan", "Karachi"],
    "Karachi": ["Multan", "Quetta"]
}

# Count the number of connections for each city
city_connections = {city: len(neighbors) for city, neighbors in cities_graph.items()}

# Data for the pie chart
cities = list(city_connections.keys())
connections = list(city_connections.values())

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(connections, labels=cities, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Set title and display the chart
plt.title('City Connections Pie Chart')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()
